# %%
import numpy as np
import pandas as pd 
import     sklearn

# %%
From sklearn.datasets import load_boston
df=load_boston()
df. Keys() #Returns all the keys of the datasets dictionary

# %%
dict_keys(['data', 'target', 'feature_names', 'DESCR','filename'])'

# %%
Print(df.DESCR)#Info about the dataset
.. _boston_dataset:
------------------
# Out:
#   File "<ipython-input-1-f960d6e8c9dc>", line 2
#     .. _boston_dataset:
#     ^
# SyntaxError: invalid syntax

# %%
Print(df.filename)

# %%
Print(df.target)

# %%
Print (df. Data)

# %%
Boston= pd. DataFrame(df.data, columns=df.featurenames) 
Boston.head()

# %%
boston['medv']=df.target
Boston. head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-3bf3729045bb> in <module>()
# ----> 1 boston['medv']=df.target
#       2 Boston. head()
#
# NameError: name 'df' is not defined

# %%
Boston.isNull()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-88eb86acfce4> in <module>()
# ----> 1 Boston.isNull()
#
# NameError: name 'Boston' is not defined

# %%
Boston.Isnull().Sum()

# %%
From sklearn. Model_selection import train_test_split
X=Boston.drop('MEDV',axis=1)
Y=Boston['MEDV']
 
X_train, x_test, Y_test=train_test_split(x,y, test_size=0.15, random_state=5)
Print(x_train.shape) 
Print(x_test.shape) 
Print(Y_train.shape) 
Print(Y_test.shape)

# %%
From sklearn. Linear_model import linearRegression
From sklearn. Metrics import mean_squared_error

# %%
#Fitting model on the training dataset
Lin_model=linearRegression() 
Lin_model.fit(x_train, Y_train)

# %%
LinearRegression (copy_
